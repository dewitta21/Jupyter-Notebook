# %% [markdown]
# ojen-izad-ixaj-ryde Anna DeWitt
#
# https://codecheck.io/private/resume/22070524142vzdaoq3k81slfxsbh9nxoif6/ojen-izad-ixaj-ryde/1AZ3WU38RN717PMGG1BPD0LFA

# %% [markdown]
# Question 1
# Assume scores is a list of integers. Fill in the following code snippets.

# %% [markdown]
# ![HW09_Q1.JPG](attachment:HW09_Q1.JPG)

# %% [markdown]
# Question 2
# Complete the following program that multiplies each element of a list by five.

# %%
values = [2, 3, 5, 7, 11]

for i in range(len(values)):
    values[i]*=5

for element in values:
    print(element)
# Out:
# 10
# 15
# 25
# 35
# 55

# %% [markdown]
# Question 3
# Complete the following program that removes the maximum value from a given list.

# %%
values = [17, 25, 5, 30, 100, 96, 48, 5, 14, 30]

i = max(values)

values.remove(i)

print(values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2456\2052714554.py in <module>
#       1 values = [17, 25, 5, 30, 100, 96, 48, 5, 14, 30]
#       2
# ----> 3 i = max(values)
#       4
#       5 values.remove(i)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# Question 4
# Complete the following program that creates a duplicate version of a list but with the elements stored in reverse order from the original.

# %%
origValues = [17, 25, 5, 30, 100, 96, 48, 5, 14, 30]
newValues = []

newValues = origValues[::-1]

print(newValues)
# Out:
# [30, 14, 5, 48, 96, 100, 30, 5, 25, 17]

# %% [markdown]
# Question 5
# Implement the fill function that fills all elements of a list with a given value. For example, the call fill(scores, 10) should fill all elements of the list scores with the value 10.

# %% [markdown]
# ![HW09_Q5.JPG](attachment:HW09_Q5.JPG)
