# %% [markdown]
# utyx-dutu-tudy-vemu Anna DeWitt

# %% [markdown]
# Question 1
# Rearrange the lines of code below to produce a program fragment that reads user input and prints whether a time (such as 9 am) is in the morning, afternoon, or evening. Prompt the user for the hour before the suffix.

# %% [markdown]
# ![HW04_Q1.JPG](attachment:HW04_Q1.JPG)

# %% [markdown]
# Question 2
# In this activity, you will trace through an example of a misaligned else statement. The code is supposed to determine whether a time (such as 9 am) is in the morning, afternoon, or evening. For each input set, click on the conditions of the if statement that are tested and then on the statement that is executed (which may be another if statement). Be sure to trace what actually happens, even though the result will not be correct.

# %% [markdown]
# ![HW04_Q2.JPG](attachment:HW04_Q2.JPG)

# %% [markdown]
# Question 3
# Fix the code from the preceding problem so that the correct greeting is produced. Be sure to properly align the if and else statements.

# %%
time = "morning"
hour = int(input("Hour: "))
suffix = input("Suffix: ")

if suffix == "pm" :
    if hour < 6 :
        time = "afternoon"
    else :
        time = "evening"
print("good", time)
# Out:
# Hour: 3
# Suffix: am
# good morning

# %% [markdown]
# ![HW04_Q3.JPG](attachment:HW04_Q3.JPG)

# %% [markdown]
# Question 4
# Complete this program that reads the times for two events, such as 3 pm and 11 am. Determine whether the first event occurs before the second event, at the same time, or after the second event. Print "Before", "Same", or "After".

# %%
time1 =  int(input("First time: "))
suffix1 = input("suffix: ")
time2 = int(input("Second time: "))
suffix2 = input("suffix: ")

if suffix1 == suffix2 :
    if time1 < time2 :
        print("Before")
    else :
        if time1 > time2 :
            print("After")
        else :
            print("Same")
else :
    if suffix1 == "am" :
        print("Before")
    else :
        print("After")
# Out:
# First time: 9
# suffix: pm
# Second time: 3
# suffix: am
# After

# %% [markdown]
# ![HW04_Q4.JPG](attachment:HW04_Q4.JPG)

# %% [markdown]
# Question 5
# Simplify the following logical conditions, assuming that n contains an integer value and b contains a Boolean value.

# %% [markdown]
# ![HW04_Q5.JPG](attachment:HW04_Q5.JPG)
