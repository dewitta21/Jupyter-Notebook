# %%
# cige-utev-gode-ukyp Anna DeWitt

# %%
# question 1
print("Hi")
print("there")
print(39 + 3)
print("39+3")
print("x =", 7 + 2)

# %% [markdown]
# ![HW1_Q1.JPG](attachment:HW1_Q1.JPG)

# %% [markdown]
# #question 2
# ![HW1_Q2.JPG](attachment:HW1_Q2.JPG)

# %% [markdown]
# #question3
# ![HW1_Q3.JPG](attachment:HW1_Q3.JPG)

# %% [markdown]
# ![HW1_Q4.JPG](attachment:HW1_Q4.JPG)

# %%
# question 4
originalPrice = 995
taxRate = 6
tax = originalPrice * taxRate / 100
price = originalPrice + tax

print(tax)
print(price)

# %% [markdown]
# ![HW1_Q5.JPG](attachment:HW1_Q5.JPG)
